# %%
pip install astropy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: astropy in c:\users\lesta\appdata\local\programs\python\python311\lib\site-packages (7.2.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\lesta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (1.24.3)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\lesta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in c:\users\lesta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (0.2026.1.19.0.42.31)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\lesta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (6.0)
# Requirement already satisfied: packaging>=22.0.0 in c:\users\lesta\appdata\local\programs\python\python311\lib\site-packages (from astropy) (23.1)
# [notice] A new release of pip is available: 23.3.2 -> 25.3
# [notice] To update, run: C:\Users\lesta\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from astropy.io import fits
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from astropy.io import fits
#       2 from pathlib import Path
#
# ModuleNotFoundError: No module named 'astropy'

# %%
fits_files = Path("data/files.lst").read_text().splitlines()

all_data = []

for fname in fits_files:
    with fits.open(data_dir / fname) as hdul:
        all_data.append(hdul[0].data)

all_data = np.array(all_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data_dir = Path("fits")
#       2 lst_file = data_dir / "file.lst"
#       4 with lst_file.open() as f:
#
# NameError: name 'Path' is not defined

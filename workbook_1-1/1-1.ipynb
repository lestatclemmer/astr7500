# %%
import sys
sys.executable
# Out:
# '/usr/bin/python3'

# %%
from astropy.io import fits
from astropy.table import Table
from pathlib import Path
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from astropy.io import fits
#       2 from astropy.table import Table
#       3 from pathlib import Path
#
# ModuleNotFoundError: No module named 'astropy'

# %%
data_dir = "fits"
lname = "files.lst"
my_path = Path(f'./{data_dir}/{lname}')

# fixing path nonsense since I put the .fits in a dir
fits_files = []

for line in Path(my_path).read_text().splitlines():
    fits_files.append(line[2:])

# inputting all the  
all_data = []

i = 0

for fname in fits_files:
    with fits.open(f'{data_dir}/{fname}') as hdul:
        all_data.append(hdul)

all_data = np.array(all_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 data_dir = "fits"
#       2 lname = "files.lst"
# ----> 3 my_path = Path(f'./{data_dir}/{lname}')
#       5 # fixing path nonsense since I put the .fits in a dir
#       6 fits_files = []
#
# NameError: name 'Path' is not defined

# %%
rows = []

with fits.open("fits/spec-0283-51959-0350.fits") as hdul:
    print(hdul.info())
    for i, hdu in enumerate(hdul):
        for key, value in hdu.header.items():
            rows.append((i, key, value, hdu.header.comments[key]))

header_table = Table(
    rows=rows,
    names=("HDU", "Keyword", "Value", "Comment")
)

header_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 rows = []
# ----> 3 with fits.open("fits/spec-0283-51959-0350.fits") as hdul:
#       4     print(hdul.info())
#       5     for i, hdu in enumerate(hdul):
#
# NameError: name 'fits' is not defined
